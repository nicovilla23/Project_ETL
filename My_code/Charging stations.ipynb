# %%
import pandas as pd
import requests as req
import numpy as np
from tqdm.notebook import tqdm
import folium
from folium.plugins import MarkerCluster

from bs4 import BeautifulSoup as bs

from joblib import Parallel, delayed
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://chargefinder.com/en/washington/charging-station/m76w89'

html = req.get(url).content 

soup = bs(html, 'html.parser')

# %%
soup.find_all('div')
# Out:
# [<div id="app"></div>]

# %%
df = pd.read_csv('/Users/nico/Desktop/ironhack/proyectos/Project_ETL/messy_data/Electric_Vehicle_Charging_Stations.csv')

# %%
df
# Out:
#                                           Station Name  \
# 0                                        BMW OF DARIEN
# 1                         Dunkin’ - Tesla Supercharger
# 2                  Town of Beacon Falls - Commuter Lot
# 3                                      OLD SAYBROOK VW
# 4                               Fairfield Rail Station
# ..                                                 ...
# 380                  Lee Partyka Chevrolet Mazda Isuzu
# 381                                        777 MAIN ST
# 382                           Norwich Public Utilities
# 383                                    Fairfield Plaza
# 384  Eastern Connecticut State University - Shakesp...
#
#              Street Address          City                    Access Days Time  \
# 0          138-142 Ledge Rd        Darien                      24 hours daily
# 1             893 E Main St       Meriden  24 hours daily; for Tesla use only
# 2             105 N Main St  Beacon Falls                      24 hours daily
# 3    319 Middlesex Turnpike  Old Saybrook                      24 hours daily
# 4          80 Mill Plain Rd     Fairfield                      24 hours daily
# ..                      ...           ...                                 ...
# 380            200 Skiff St        Hamden           Dealership business hours
# 381            71 Asylum St      Hartford                      24 hours daily
# 382           173 N Main St       Norwich                      24 hours daily
# 383          116 Danbury Rd   New Milford                      24 hours daily
# 384       24 Charger Oak Dr   Willimantic                      24 hours daily
#
#     EV Level1 EVSE Num EV Level2 EVSE Num EV DC Fast Count EV Other Info  \
# 0                 NONE                  2             NONE          NONE
# 1                 NONE               NONE                8          NONE
# 2                 NONE                  1             NONE          NONE
# 3                 NONE                  2             NONE          NONE
# 4                 NONE                  2             NONE          NONE
# ..                 ...                ...              ...           ...
# 380               NONE                  3             NONE          NONE
# 381               NONE                 10                1          NONE
# 382               NONE                  4             NONE          NONE
# 383               NONE               NONE                1          NONE
# 384               NONE                  4             NONE          NONE
#
#                  New Georeferenced Column
# 0           POINT (-73.4764687 41.072882)
# 1            POINT (-72.773473 41.527367)
# 2    POINT (-73.065583 41.44548100000001)
# 3             POINT (-72.3825 41.3102778)
# 4            POINT (-73.264511 41.143125)
# ..                                    ...
# 380        POINT (-72.9100121 41.3729709)
# 381          POINT (-72.674468 41.766676)
# 382  POINT (-72.063516 41.52757900000001)
# 383            POINT (-73.41763 41.55735)
# 384         POINT (-72.208134 41.7385909)
#
# [385 rows x 9 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Station Name              385 non-null    object
#  1   Street Address            385 non-null    object
#  2   City                      385 non-null    object
#  3   Access Days Time          385 non-null    object
#  4   EV Level1 EVSE Num        385 non-null    object
#  5   EV Level2 EVSE Num        385 non-null    object
#  6   EV DC Fast Count          385 non-null    object
#  7   EV Other Info             385 non-null    object
#  8   New Georeferenced Column  385 non-null    object
# dtypes: object(9)
# memory usage: 237.7 KB

# %%
df1 = df.replace('NONE',np.nan)

# %%
df1.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Station Name              385 non-null    object
#  1   Street Address            385 non-null    object
#  2   City                      385 non-null    object
#  3   Access Days Time          385 non-null    object
#  4   EV Level1 EVSE Num        9 non-null      object
#  5   EV Level2 EVSE Num        341 non-null    object
#  6   EV DC Fast Count          54 non-null     object
#  7   EV Other Info             2 non-null      object
#  8   New Georeferenced Column  385 non-null    object
# dtypes: object(9)
# memory usage: 205.6 KB

# %%
df1.drop(columns= 'EV Level1 EVSE Num',inplace=True)
df1.drop(columns= 'EV DC Fast Count',inplace=True)
df1.drop(columns= 'EV Other Info',inplace=True)

# %%
df1 = df1.dropna()

# %%
df1.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341 entries, 0 to 384
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Station Name              341 non-null    object
#  1   Street Address            341 non-null    object
#  2   City                      341 non-null    object
#  3   Access Days Time          341 non-null    object
#  4   EV Level2 EVSE Num        341 non-null    object
#  5   New Georeferenced Column  341 non-null    object
# dtypes: object(6)
# memory usage: 152.1 KB

# %%
df1 = df1.drop_duplicates()

# %%
df1.shape
# Out:
# (341, 6)

# %%
df1.City.unique()
# Out:
# array(['Darien', 'Beacon Falls', 'Old Saybrook', 'Fairfield', 'Norwich',
#        'Glastonbury', 'Groton', 'Waterbury', 'Farmington', 'Shelton',
#        'Wallingford', 'Rocky Hill', 'New Haven', 'Easton', 'Colebrook',
#        'Mystic', 'Windsor Locks', 'Storrs', 'Madison', 'New Britain',
#        'Mansfield', 'Torrington', 'Harwinton', 'Middletown',
#        'North Windham', 'Westbrook', 'Bristol', 'Branford', 'Manchester',
#        'Meriden', 'Guilford', 'Simsbury', 'Hartford', 'Stratford',
#        'Stonington', 'Westport', 'Stamford', 'Niantic', 'New Milford',
#        'Newtown', 'Bloomfield', 'Washington', 'North Haven',
#        'Stafford Springs', 'West Hartford', 'Newington', 'Norwalk',
#        'Southbury', 'Ridgefield', 'Mashantucket', 'East Hartford',
#        'Ledyard', 'Plainville', 'Greenwich', 'New London', 'Windham',
#        'Danbury', 'Canton', 'Durham', 'Southington', 'New Fairfield',
#        'Orange', 'West Haven', 'Bridgeport', 'Coventry', 'Uncasville',
#        'Enfield', 'Ellington', 'Berlin', 'Kent', 'Putnam', 'Milford',
#        'Norfolk', 'Clinton', 'Pomfret', 'Willimantic', 'Somersville',
#        'Hamden', 'West Simsbury', 'Brooklyn', 'East Hampton',
#        'Wethersfield', 'Woodbridge', 'East Haven', 'Barkhamsted',
#        'New Canaan', 'Hebron', 'Trumbull', 'Bethany',
#        'Rte 47, Washington', 'Cheshire', 'Plantsville', 'Bethel',
#        'South Windsor', 'Lakeville', 'Old Lyme', 'Yantic', 'Killingly',
#        'Woodstock', 'Wilton', 'Burlington', 'Suffield', 'North Branford',
#        'Lyme', 'Seymour', 'East Granby', 'Deep River', 'Rockyhill',
#        'Roxbury', 'Morris', 'Oxford', 'East Haddam', 'Waterford',
#        'Middlebury', 'Salisbury', 'Vernon'], dtype=object)

# %%
df1[['Latitude', 'Longitude']] = df1['New Georeferenced Column'].str.strip('POINT ()').str.split(expand=True)

# %%
df1.drop(columns='New Georeferenced Column',inplace= True )

# %%
df1['Access Days Time'].unique()
# Out:
# array(['24 hours daily',
#        '24 hours daily; guest use only; see front desk for access',
#        '6am-12am daily', 'Dealership business hours',
#        '24 hours daily; for customer use only; see front desk for access',
#        '24 hours daily; pay lot', '24 hours daily; for customer use only',
#        '8am-3pm M-F', '24 hours daily; permit lot', '6am-12pm daily',
#        '7am-7pm M-F', 'Garage business hours',
#        'MO: Not Specified; TU: Not Specified; WE: Not Specified; TH: Not Specified; FR: Not Specified; SA: Not Specified; SU: Not Specified',
#        'Restricted to garage hours; pay lot',
#        'MO: 12:00am-12:00am; TU: 12:00am-12:00am; WE: 12:00am-12:00am; TH: 12:00am-12:00am; FR: 12:00am-12:00am; SA: 12:00am-12:00am; SU: 12:00am-12:00am',
#        'School hours', '6am-12am',
#        '8am-10pm daily; for customer use only; see inside for access',
#        '24 hours daily; for member use only; see valet for access',
#        '24 hours daily; overnight valet fee',
#        '24 hours daily; priority for customer use',
#        '24 hours daily; see valet for access', '6am-6pm daily',
#        '24 hours daily; for customer use only; see valet for access',
#        '8:30am-4:30pm M-F', 'Garage business hours; pay lot',
#        '24 hours daily; 2 hour limit',
#        'Dealership business hours; for customer use only',
#        'MON: 24 hours | TUE: 24 hours | WED: 24 hours | THU: 24 hours | FRI: 24 hours | SAT: 24 hours | SUN: 24 hours',
#        'After 5pm daily', 'Restaurant business hours; for guest use only',
#        'Dawn to dusk',
#        'Dealership business hours; contact 860-892-6000 for more information',
#        'Store business hours; see inside for access',
#        'Dealership business hours; customer use only',
#        'Parking lot hours',
#        '24 hours daily; priority for Connecticut Green Bank employees',
#        '9am-5pm M-F', 'Lot business hours', 'For guest use only',
#        '11am-10pm daily', '7am-10pm M-F, 8am-5pm Sat',
#        '10am-8pm M-Th, 10am-6pm F, 10am-5pm Sat, 1pm-5pm Sun (Sunday hours in winter only)',
#        'Dealership business hours; Ford use only',
#        '24 hours daily; pay lot; see attendant for access',
#        '24 hours daily; see front desk for access', '8am-5pm M-F',
#        '24 hours daily; see code on the face of charger or ask librarian to initiate charge',
#        'Park business hours', 'Parking lot business hours'], dtype=object)

# %%
def clean(x):
    x=str(x)
    if '24' in x:
        return '24 Hours'
    else:
        return 'Regular'
df1['Access Days Time'] = df1['Access Days Time'].apply(clean)

# %% [markdown]
# #

# %%
df1
# Out:
#                                           Station Name  \
# 0                                        BMW OF DARIEN
# 2                  Town of Beacon Falls - Commuter Lot
# 3                                      OLD SAYBROOK VW
# 4                               Fairfield Rail Station
# 5                                            FOUNDRY66
# ..                                                 ...
# 379                                      Yankee Doodle
# 380                  Lee Partyka Chevrolet Mazda Isuzu
# 381                                        777 MAIN ST
# 382                           Norwich Public Utilities
# 384  Eastern Connecticut State University - Shakesp...
#
#              Street Address          City Access Days Time EV Level2 EVSE Num  \
# 0          138-142 Ledge Rd        Darien         24 Hours                  2
# 2             105 N Main St  Beacon Falls         24 Hours                  1
# 3    319 Middlesex Turnpike  Old Saybrook         24 Hours                  2
# 4          80 Mill Plain Rd     Fairfield         24 Hours                  2
# 5            50 Franklin St       Norwich         24 Hours                  2
# ..                      ...           ...              ...                ...
# 379    10 Burnell Boulevard       Norwalk         24 Hours                  1
# 380            200 Skiff St        Hamden          Regular                  3
# 381            71 Asylum St      Hartford         24 Hours                 10
# 382           173 N Main St       Norwich         24 Hours                  4
# 384       24 Charger Oak Dr   Willimantic         24 Hours                  4
#
#         Latitude          Longitude
# 0    -73.4764687          41.072882
# 2     -73.065583  41.44548100000001
# 3       -72.3825         41.3102778
# 4     -73.264511          41.143125
# 5    -72.0741188          41.525611
# ..           ...                ...
# 379   -73.414932           41.11803
# 380  -72.9100121         41.3729709
# 381   -72.674468          41.766676
# 382   -72.063516  41.52757900000001
# 384   -72.208134         41.7385909
#
# [341 rows x 7 columns]

# %%
df1 = df1.rename(columns= {'EV Level2 EVSE Num': 'EVSE units'})

# %%
df1
# Out:
#                                           Station Name  \
# 0                                        BMW OF DARIEN
# 2                  Town of Beacon Falls - Commuter Lot
# 3                                      OLD SAYBROOK VW
# 4                               Fairfield Rail Station
# 5                                            FOUNDRY66
# ..                                                 ...
# 379                                      Yankee Doodle
# 380                  Lee Partyka Chevrolet Mazda Isuzu
# 381                                        777 MAIN ST
# 382                           Norwich Public Utilities
# 384  Eastern Connecticut State University - Shakesp...
#
#              Street Address          City Access Days Time EVSE units  \
# 0          138-142 Ledge Rd        Darien         24 Hours          2
# 2             105 N Main St  Beacon Falls         24 Hours          1
# 3    319 Middlesex Turnpike  Old Saybrook         24 Hours          2
# 4          80 Mill Plain Rd     Fairfield         24 Hours          2
# 5            50 Franklin St       Norwich         24 Hours          2
# ..                      ...           ...              ...        ...
# 379    10 Burnell Boulevard       Norwalk         24 Hours          1
# 380            200 Skiff St        Hamden          Regular          3
# 381            71 Asylum St      Hartford         24 Hours         10
# 382           173 N Main St       Norwich         24 Hours          4
# 384       24 Charger Oak Dr   Willimantic         24 Hours          4
#
#         Latitude          Longitude
# 0    -73.4764687          41.072882
# 2     -73.065583  41.44548100000001
# 3       -72.3825         41.3102778
# 4     -73.264511          41.143125
# 5    -72.0741188          41.525611
# ..           ...                ...
# 379   -73.414932           41.11803
# 380  -72.9100121         41.3729709
# 381   -72.674468          41.766676
# 382   -72.063516  41.52757900000001
# 384   -72.208134         41.7385909
#
# [341 rows x 7 columns]

# %%
m = folium.Map(location= [ 41.7385909, -73.414932], tiles = 'OpenStreetMap', zoom_start = 10)

# %%
df1['EVSE units']= df1['EVSE units'].astype('int64')

# %%
df1['Latitude']= df1['Latitude'].astype('float64')

# %%
df1['Longitude']= df1['Longitude'].astype('float64')

# %%
for i,row in df1.iterrows():
    latitude = df1.at[i, 'Latitude']
    longitude = df1.at[i, 'Longitude']
    name = df1.at[i, 'Station Name']
    
    folium.Marker(location= [longitude, latitude],popup= name,icon= folium.Icon(color= 'blue')).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ff75ffa9fc289aa7cb92c2745c2112d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ff75ffa9fc289aa7cb92c2745c2112d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ff75ffa9fc289aa7cb92c2745c2112d = L.map(
#                 &quot;map_9ff75ffa9fc289aa7cb92c2745c2112d&quot;,
#                 {
#                     center: [41.7385909, -73.414932],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e1b111b9b56246ee112e440f8731f43 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9ff75ffa9fc289aa7cb92c2745c2112d);
#
#
#             var marker_e4ab4c04b81c1864f5d57048957e5c00 = L.marker(
#                 [41.072882, -73.4764687],
#                 {}
#             ).addTo(map_9ff75ffa9fc289aa7cb92c2745c2112d);
#
#
#             var icon_2c9f9a011845644a886486c8cf9183f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4ab4c04b81c1864f5d57048957e5c00.setIcon(icon_2c9f9a011845644a886486c8cf9183f5);
#
#
#         var popup_63da2c625b9b0c3df39a76b4cc03be43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_737ed14b3dc689b46d0b41981069aa2b = $(`&lt;div id=&quot;html_737ed14b3dc689b46d0b41981069aa2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BMW OF DARIEN&lt;/div&gt;`)[0];
#                 popup_63da2c625b9b0c3df39a76b4cc03be43.setContent(html_737ed14b3dc689b46d0b41981069aa2b);
#
#
#
#         marker_e4ab4c04b81c1864f5d57048957e5c00.bindPopup(popup_63da2c625b9b0c3df39a76b4cc03be43)
#         ;
#
#
#
#
#             var marker_e956c589fdc243f41404333e8c363d54 = L.marker(
#                 [41.44548100000001, -73.065583],
#                 {}
#             ).addTo(map_9ff75ffa9fc289aa7cb92c2745c2112d);
#
#
#             var icon_c2dec0e1f16a26e055ee0c005c7998f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e956c589fdc243f41404333e8c363d54.setIcon(icon_c2dec0e1f16a26e055ee0c005c7998f3);
#
#
#         var popup_190dbf761cd4f829f8157548de8c64fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fcd42b66bbb1da6d527a800356bdb6d2 = $(`&lt;div id=&quot;html_fcd42b66bbb1da6d527a800356bdb6d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town of Beacon Falls - Commuter Lot&lt;/div&gt;`)[0];
#                 popup_190dbf761cd4f829f8157548de8c64fc.setContent(html_fcd42b66bbb1da6d527a800356bdb6d2);
#
#
#
#         marker_e956c589fdc243f41404333e8c363d54.bindPopup(popup_190dbf761cd4f829f8157548de8c64fc)
#         ;
#
#
#
#
#             var marker_fc6be64228e95493e9e8d955d42dde65 = L.marker(
#                 [41.3102778, -72.3825],
#                 {}
#             ).addTo(map_9ff75ffa9fc289aa7cb92c2745c2112d);
#
#
#             var icon_8583c260d53b756083e6072256f71b1f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc6be64228e95493e9e8d955d42dde65.setIcon(icon_8583c260d53b756083e6072256f71b1f);
#
#
#         var popup_4e17f4b6fde9001f3fc16c5600d1c67a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7418515f2088ca23352faf57953e5cd = $(`&lt;div id=&quot;html_a7418515f2088ca23352faf57953e5cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OLD SAYBROOK VW&lt;/div&gt;`)[0];
#                 popup_4e17f4b6fde9001f3fc16c5600d1c67a.setContent(html_a7418515f2088ca23352faf57953e5cd);
#
#
#
#         marker_fc6be64228e95493e9e8d955d42dde65.bindPopup(popup_4e17f4b6fde9001f3fc16c5600d1c67a)
#         ;
#
#
#
#
#             var marker_6c6ecf34124437522daf4243cb02eccc = L.marker(
#                 [41.143125, -73.264511],
#                 {}
#             ).addTo(map_9ff75ffa9fc289aa7cb92c2745c2112d);
#
#
#             var icon_8a000341c0578bc8e2f93d792872ca7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rota
